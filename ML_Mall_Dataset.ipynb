# %% [markdown]
# <a href="https://colab.research.google.com/github/Swagatpawar/Mall-Dataset/blob/main/ML_Mall_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90e04394-2980-491f-8561-38693f862b85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90e04394-2980-491f-8561-38693f862b85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.size
# Out:
# 1000

# %%
df.columns=df.columns.str.strip().str.lower().str.replace(r"[()$]","",regex=True).str.replace("-","_").str.replace(" ","_")

# %%
df.head()
# Out:
#    customerid  gender  age  annual_income_k  spending_score_1_100
# 0           1    Male   19               15                    39
# 1           2    Male   21               15                    81
# 2           3  Female   20               16                     6
# 3           4  Female   23               16                    77
# 4           5  Female   31               17                    40

# %%
df.describe()
# Out:
#        customerid         age  annual_income_k  spending_score_1_100
# count  200.000000  200.000000       200.000000            200.000000
# mean   100.500000   38.850000        60.560000             50.200000
# std     57.879185   13.969007        26.264721             25.823522
# min      1.000000   18.000000        15.000000              1.000000
# 25%     50.750000   28.750000        41.500000             34.750000
# 50%    100.500000   36.000000        61.500000             50.000000
# 75%    150.250000   49.000000        78.000000             73.000000
# max    200.000000   70.000000       137.000000             99.000000

# %%
# selectin feature

x=df[['annual_income_k','spending_score_1_100']]
x.head()
# Out:
#    annual_income_k  spending_score_1_100
# 0               15                    39
# 1               15                    81
# 2               16                     6
# 3               16                    77
# 4               17                    40

# %%
# since there is no label, the model can use onlyis distance b/w pointsm

# %%
# visualing raw data

import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x['annual_income_k'],x['spending_score_1_100'])
plt.xlabel('annual_income_k')
plt.ylabel('spending_score_1_100')
plt.show()

# %%
# #k means tries to group points so that points in the
# #same group are close to each other

# from sklearn.cluster import KMeans

# kmeans = KMeans(n_clusters = 5, random_state=42)
# labels = kmeans.fit_predict(x)


# # n_cluster, divide the customer into 5 groups
# # fit (x) - looks t all data points in x, place
# # 5 random cetroids
# # ssigns each point to center  of assigns points in
# # iteation
# # repeats until stable
# # for each data point returns which cluster it belongs to
# # represents them the with numeric values

# %%
# labels[:10]

# %%
# df['cluster']=labels
# df.head()
# Out:
#    customerid  gender  age  annual_income_k  spending_score_1_100  cluster
# 0           1    Male   19               15                    39        4
# 1           2    Male   21               15                    81        2
# 2           3  Female   20               16                     6        4
# 3           4  Female   23               16                    77        2
# 4           5  Female   31               17                    40        4

# %%
# # visualize clusters

# plt.scatter(
#     x['annual_income_k'],
#     x['spending_score_1_100'],
#     c=labels
# )

# plt.xlabel('annual_income_k')
# plt.ylabel('spending_score_1_100')
# plt.title('customer segments')
# plt.show()

# %%
# elbow method
# it helps to find how many grops to use

from sklearn.cluster import KMeans

wcss = []
for  k in range(1,11):
  kmeans = KMeans(n_clusters = k, random_state =42)
  kmeans.fit(x)
  wcss.append(kmeans.inertia_)

  # wcss - Within Cluster sum of np.square
  #Lower wcss- tightly clusters
  # higher wcss-messy cluster

  # we will store this for each kmeans
  # ech loop - new model- different number of cluster

# %%
plt.plot(range(1,11),wcss)

# %%
# selectin feature

x=df[['annual_income_k','spending_score_1_100']]
x.head()
# Out:
#    annual_income_k  spending_score_1_100
# 0               15                    39
# 1               15                    81
# 2               16                     6
# 3               16                    77
# 4               17                    40

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x['annual_income_k'],x['spending_score_1_100'])
plt.xlabel('annual_income_k')
plt.ylabel('spending_score_1_100')
plt.show()

# %%
 plt.scatter(
     x['annual_income_k'],
     x['spending_score_1_100'],
     c=labels
 )

 plt.xlabel('annual_income_k')
 plt.ylabel('spending_score_1_100')
 plt.title('customer segments')
 plt.show()

# %%
# applying PCA here
# Principal Component Analysis -PCA

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)

# Components=2-reducing data 2

# %%
# visualize cluster using PCA

plt.scatter(
    x_pca[:,0],
    x_pca[:,1],
    c=labels
)

# %%
df.groupby('cluster')[['annual_income_k','spending_score_1_100']].mean()
# Out:
#          annual_income_k  spending_score_1_100
# cluster
# 0              55.296296             49.518519
# 1              86.538462             82.128205
# 2              25.727273             79.363636
# 3              88.200000             17.114286
# 4              26.304348             20.913043

# %%
df['segment'] =df['cluster'].map({
    0:'mid income - mid spend',
    1:'high income - high spend',
    2:'low income - high spend',
    3:'high income - low spend',
    4:'low income - low spend'
})

# %%
df.head()
# Out:
#    customerid  gender  age  annual_income_k  spending_score_1_100  cluster  \
# 0           1    Male   19               15                    39        4
# 1           2    Male   21               15                    81        2
# 2           3  Female   20               16                     6        4
# 3           4  Female   23               16                    77        2
# 4           5  Female   31               17                    40        4
#
#                    segment
# 0   low income - low spend
# 1  low income - high spend
# 2   low income - low spend
# 3  low income - high spend
# 4   low income - low spend

# %%
plt.figure(figsize=(10,10))
for segment_name,cluster_id in df[['segment','cluster']].drop_duplicates().values:
  subset = df[df['cluster']== cluster_id]

  plt.scatter(
      subset['annual_income_k'],
      subset['spending_score_1_100'],
      label=segment_name
  )

plt.xlabel('annual_income_k')
plt.ylabel('spending_score_1_100')
plt.title('cluster segments')
plt.legend(title='customer segment')
plt.show()
